# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import pickle
import os
from demo_utils import *
# %matplotlib inline
sns.set_style('ticks')
plt.rcParams['font.size'] = 20

# %%
# transform_files(): transform the orginal files in the fild "tmp_re" into the format for figures

# # fig2-beta
# beta = [0, 4, 7]
# sigma = [0.01]
# gamma_plus = [1.0]
# gamma_minus = [-0.1]

# for s in sigma:
#     for b in beta:
#         for gp in gamma_plus:
#             for gm in gamma_minus:
#                 transform_files(b, gp, gm, s)


# # fig2-gamma plus
# beta = [7]
# sigma = [0.01]
# gamma_plus = [0.0, 0.3, 1]
# gamma_minus = [-0.1]

# for s in sigma:
#     for b in beta:
#         for gp in gamma_plus:
#             for gm in gamma_minus:
#                 transform_files(b, gp, gm, s)

# # fig3-gamma minus
# beta = [7]
# sigma = [0.01]
# gamma_plus = [1.0]
# gamma_minus = [-0.1, -0.3, -0.9]


# for s in sigma:
#     for b in beta:
#         for gp in gamma_plus:
#             for gm in gamma_minus:
#                 transform_files(b, gp, gm, s)

# # fig4-sigma
# beta = [10]
# sigma = [0.04, 0.07, 0.16]
# gamma_plus = [1.0]
# gamma_minus = [-0.1]

# for s in sigma:
#     for b in beta:
#         for gp in gamma_plus:
#             for gm in gamma_minus:
#                 transform_files(b, gp, gm, s)

# %%
# fig2-beta
get_figs(beta=[0, 4, 7], fig_type='beta')

# %%
# fig2-gamma plus
get_figs(gamma_plus=[0.0, 0.3, 1], fig_type='gamma_plus')

# %%
# fig3-gamma minus
get_figs(gamma_minus=[-0.1, -0.3, -0.9], fig_type='gamma_minus')

# %%
# fig3-sigma
get_figs(sigma=[0.04, 0.07, 0.16], fig_type='sigma')
